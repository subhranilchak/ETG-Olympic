# %%
import pandas as pd

# %%
df = pd.read_csv("summer olympics.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#        Year    City      Sport  ... Gender                       Event   Medal
# 0      1896  Athens   Aquatics  ...    Men              100M Freestyle    Gold
# 1      1896  Athens   Aquatics  ...    Men              100M Freestyle  Silver
# 2      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Bronze
# 3      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors    Gold
# 4      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Silver
# ...     ...     ...        ...  ...    ...                         ...     ...
# 31160  2012  London  Wrestling  ...    Men                    Wg 84 KG  Bronze
# 31161  2012  London  Wrestling  ...    Men                    Wg 96 KG    Gold
# 31162  2012  London  Wrestling  ...    Men                    Wg 96 KG  Silver
# 31163  2012  London  Wrestling  ...    Men                    Wg 96 KG  Bronze
# 31164  2012  London  Wrestling  ...    Men                    Wg 96 KG  Bronze
#
# [31165 rows x 9 columns]

# %% [markdown]
# ## 1. In how many cities Summer Olympics is held so far?

# %%
df['City'].unique()
# Out:
# array(['Athens', 'Paris', 'St Louis', 'London', 'Stockholm', 'Antwerp',
#        'Amsterdam', 'Los Angeles', 'Berlin', 'Helsinki',
#        'Melbourne / Stockholm', 'Rome', 'Tokyo', 'Mexico', 'Munich',
#        'Montreal', 'Moscow', 'Seoul', 'Barcelona', 'Atlanta', 'Sydney',
#        'Beijing'], dtype=object)

# %% [markdown]
# ## 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
data = []
for Sport in df['Sport'].unique():
  data.append([Sport, len(df[df['Sport'] == Sport])])

pd.DataFrame(data, columns = ['Sport','Gold']).sort_values(by = 'Gold', ascending = False).head().plot(x='Sport',y='Gold',kind='bar', figsize=(20,5))

# %% [markdown]
# ## 3. Which sport is having most number of medals so far? (Top 5)

# %%
data = []
for Sport in df['Sport'].unique():
  data.append([Sport, len(df[df['Sport'] == Sport])])

pd.DataFrame(data, columns = ['Sport','Medal']).sort_values(by = 'Medal', ascending = False).head().plot(x='Sport',y='Medal',kind='bar', figsize=(20,5))

# %% [markdown]
# ## 4. Which player has won most number of medals? (Top 5)

# %%
data = []
for Athlete in df['Athlete'].unique():
  data.append([Athlete, len(df[df['Athlete'] == Athlete])])

pd.DataFrame(data, columns = ['Athlete','Medal']).sort_values(by = 'Medal', ascending = False).head().plot(x='Athlete',y='Medal',kind='bar', figsize=(20,5))

# %% [markdown]
# ### 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
data = []
for Athlete in df['Athlete'].unique():
  data.append([Athlete, len(df[df['Athlete'] == Athlete])])

pd.DataFrame(data, columns = ['Athlete','Gold']).sort_values(by = 'Gold', ascending = False).head().plot(x='Athlete',y='Gold',kind='bar', figsize=(20,5))

# %% [markdown]
# ### 6. In which year India won first Gold Medal in Summer Olympics?

# %%
df = df[df['Country'] == 'IND']
df = df[df['Medal'] == 'Gold']

data = []

for Year in df['Year'].unique():
  data.append([Year, len(df[df['Year'] == Year])])

pd.DataFrame(data, columns = ['Year','freq']).sort_values(by = 'freq', ascending = False).plot(x='Year',y='freq',kind='bar', figsize=(20,5), color='orange')

# %%
# ACCORDING TO ABOVE GRAPH INDIA GOT IT'S FIRST GOLD MEDAL IN 1928

# %%
df[df['Country'] == 'IND']
df[df['Medal'] == 'Gold']
# Out:
#        Year       City     Sport  ... Gender                     Event Medal
# 5512   1928  Amsterdam    Hockey  ...    Men                    Hockey  Gold
# 5513   1928  Amsterdam    Hockey  ...    Men                    Hockey  Gold
# 5514   1928  Amsterdam    Hockey  ...    Men                    Hockey  Gold
# 5515   1928  Amsterdam    Hockey  ...    Men                    Hockey  Gold
# 5516   1928  Amsterdam    Hockey  ...    Men                    Hockey  Gold
# ...     ...        ...       ...  ...    ...                       ...   ...
# 16099  1980     Moscow    Hockey  ...    Men                    Hockey  Gold
# 16100  1980     Moscow    Hockey  ...    Men                    Hockey  Gold
# 16101  1980     Moscow    Hockey  ...    Men                    Hockey  Gold
# 16102  1980     Moscow    Hockey  ...    Men                    Hockey  Gold
# 28856  2008    Beijing  Shooting  ...    Men  10M Air Rifle (60 Shots)  Gold
#
# [128 rows x 9 columns]

# %% [markdown]
# ### 7. Which event is most popular in terms on number of players? (Top 5)

# %%
data = []

for Athlete in df['Athlete'].unique():
  data.append([Athlete, len(df[df['Athlete'] == Athlete])])

pd.DataFrame(data, columns = ['Athlete','Event']).sort_values(by = 'Event', ascending = False).plot(x='Athlete',y='Event',kind='bar', figsize=(20,5))

# %%
data = []

for Athlete in df['Athlete'].unique():
  data.append([Athlete, len(df[df['Athlete'] == Athlete])])

pd.DataFrame(data, columns = ['Athlete','Event']).sort_values(by = 'Event', ascending = False).head().plot(x='Athlete',y='Event',kind='bar', figsize=(20,5))

# %% [markdown]
# ### 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
df=pd.read_csv('summer olympics.csv')

df = df[df['Medal'] == 'Gold']
df = df[df['Gender'] == 'Women']

data = []

for Year in df['Year'].unique():
  data.append([Year, len(df[df['Year'] == Year])])

pd.DataFrame(data, columns = ['Year','Sport']).sort_values(by = 'Sport', ascending = False).plot(x='Year',y='Sport',kind='bar', figsize=(20,5))

# %%
df=pd.read_csv('summer olympics.csv')

df = df[df['Medal'] == 'Gold']
df = df[df['Gender'] == 'Women']

data = []

for Year in df['Year'].unique():
  data.append([Year, len(df[df['Year'] == Year])])

pd.DataFrame(data, columns = ['Year','Sport']).sort_values(by = 'Sport', ascending = False).head().plot(x='Year',y='Sport',kind='bar', figsize=(20,5))
